# %% [markdown]
# ## 🚧 Setup Zone
#
# ### Prerequisites
#
# Before running this notebook, ensure you have:
# 1. Completed the environment setup from the main tutorial
# 2. The `stocks.db` DuckDB database in the `data/` directory
# 3. DuckDB package installed
#
# ```bash
# pip install duckdb
# ```

# %% [markdown]
# ---
# ## ✅ End of Setup Zone
# ---

# %% [markdown]
# ## 📦 Import Libraries
#
# We'll use three main packages:
#
# | Package | Purpose |
# |---------|---------|
# | `duckdb` | Read data from local DuckDB database |
# | `snowflake.core` | Python API for managing Snowflake objects |
# | `snowflake.snowpark` | DataFrame API for data transformations |

# %%
# Standard library
import os
import time
from datetime import date, datetime

# DuckDB for local database access
import duckdb
import pandas as pd

# Snowflake imports
from snowflake.snowpark import Session
from snowflake.snowpark import functions as F
from snowflake.core import Root, CreateMode
from snowflake.core.database import Database
from snowflake.core.schema import Schema
from snowflake.core.warehouse import Warehouse
from snowflake.core.table import Table, TableColumn
from snowflake.core.role import Role, Securable
from snowflake.core.dynamic_table import DynamicTableCollection

# %% [markdown]
# ## 🦆 Explore DuckDB Database
#
# First, let's connect to the local DuckDB database and explore its structure.

# %%
# Connect to DuckDB database
duckdb_path = "./data/stocks.db"
duck_conn = duckdb.connect(duckdb_path, read_only=True)

print(f"🦆 Connected to DuckDB database: {duckdb_path}")
# Out:
# 🦆 Connected to DuckDB database: ./data/stocks.db

# %%
# List all tables in the DuckDB database
tables_df = duck_conn.execute("SHOW TABLES").fetchdf()
print("Tables in DuckDB database:")
display(tables_df)
# Out:
# Tables in DuckDB database:
#              name
# 0       exchanges
# 1      index_list
# 2    index_quotes
# 3    risk_premium
# 4   stock_metrics
# 5  stock_profiles
# 6    stock_quotes
# 7   stock_tickers

# %%
# Get detailed schema information for each table
for table_name in tables_df['name'].tolist():
    print(f"\n📋 Schema for table '{table_name}':")
    schema_df = duck_conn.execute(f"DESCRIBE {table_name}").fetchdf()
    display(schema_df)
    
    # Get row count
    count = duck_conn.execute(f"SELECT COUNT(*) FROM {table_name}").fetchone()[0]
    print(f"Row count: {count:,}")
# Out:
# 📋 Schema for table 'exchanges':
#     column_name column_type null   key default extra
# 0      exchange     VARCHAR  YES  None    None  None
# 1          name     VARCHAR  YES  None    None  None
# 2   countryName     VARCHAR  YES  None    None  None
# 3   countryCode     VARCHAR  YES  None    None  None
# 4  symbolSuffix     VARCHAR  YES  None    None  None
# 5         delay     VARCHAR  YES  None    None  None
# Row count: 14
#
# 📋 Schema for table 'index_list':
#   column_name column_type null   key default extra
# 0      symbol     VARCHAR  YES  None    None  None
# 1        name     VARCHAR  YES  None    None  None
# 2    exchange     VARCHAR  YES  None    None  None
# 3    currency     VARCHAR  YES  None    None  None
# Row count: 36
#
# 📋 Schema for table 'index_quotes':
#   column_name column_type null   key default extra
# 0      symbol     VARCHAR  YES  None    None  None
# 1        date        DATE  YES  None    None  None
# 2       price      DOUBLE  YES  None    None  None
# 3      volume      BIGINT  YES  None    None  None
# Row count: 111,946
#
# 📋 Schema for table 'risk_premium':
#               column_name column_type null   key default extra
# 0                 country     VARCHAR  YES  None    None  None
# 1               continent     VARCHAR  YES  None    None  None
# 2      countryRiskPremium      DOUBLE  YES  None    None  None
# 3  totalEquityRiskPremium      DOUBLE  YES  None    None  None
# Row count: 44
#
# 📋 Schema for table 'stock_metrics':
#                  column_name   column_type null   key default extra
# 0                     symbol       VARCHAR  YES  None    None  None
# 1                       date  TIMESTAMP_MS  YES  None    None  None
# 2                 fiscalYear        BIGINT  YES  None    None  None
# 3                     period       VARCHAR  YES  None    None  None
# 4           reportedCurrency       VARCHAR  YES  None    None  None
# ..                       ...           ...  ...   ...     ...   ...
# 102         priceToFairValue        DOUBLE  YES  None    None  None
# 103          debtToMarketCap        DOUBLE  YES  None    None  None
# 104         effectiveTaxRate        DOUBLE  YES  None    None  None
# 105  enterpriseValueMultiple        DOUBLE  YES  None    None  None
# 106         dividendPerShare        DOUBLE  YES  None    None  None
#
# [107 rows x 6 columns]
# Row count: 129,384
#
# 📋 Schema for table 'stock_profiles':
#           column_name column_type null   key default extra
# 0           marketCap      BIGINT  YES  None    None  None
# 1             ipoDate     VARCHAR  YES  None    None  None
# 2                 ceo     VARCHAR  YES  None    None  None
# 3               cusip     VARCHAR  YES  None    None  None
# 4              volume      BIGINT  YES  None    None  None
# 5              sector     VARCHAR  YES  None    None  None
# 6               image     VARCHAR  YES  None    None  None
# 7             address     VARCHAR  YES  None    None  None
# 8               price      DOUBLE  YES  None    None  None
# 9         companyName     VARCHAR  YES  None    None  None
# 10                cik     VARCHAR  YES  None    None  None
# 11               beta      DOUBLE  YES  None    None  None
# 12              range     VARCHAR  YES  None    None  None
# 13             isFund     VARCHAR  YES  None    None  None
# 14              phone     VARCHAR  YES  None    None  None
# 15               isin     VARCHAR  YES  None    None  None
# 16       lastDividend      DOUBLE  YES  None    None  None
# 17              isEtf     VARCHAR  YES  None    None  None
# 18      averageVolume      DOUBLE  YES  None    None  None
# 19           exchange     VARCHAR  YES  None    None  None
# 20  isActivelyTrading     VARCHAR  YES  None    None  None
# 21              state     VARCHAR  YES  None    None  None
# 22             change      DOUBLE  YES  None    None  None
# 23            country     VARCHAR  YES  None    None  None
# 24              isAdr     VARCHAR  YES  None    None  None
# 25        description     VARCHAR  YES  None    None  None
# 26       defaultImage     VARCHAR  YES  None    None  None
# 27               city     VARCHAR  YES  None    None  None
# 28           currency     VARCHAR  YES  None    None  None
# 29            website     VARCHAR  YES  None    None  None
# 30                zip     VARCHAR  YES  None    None  None
# 31   exchangeFullName     VARCHAR  YES  None    None  None
# 32             symbol     VARCHAR  YES  None    None  None
# 33   changePercentage      DOUBLE  YES  None    None  None
# 34  fullTimeEmployees     VARCHAR  YES  None    None  None
# 35           industry     VARCHAR  YES  None    None  None
# Row count: 11,895
#
# 📋 Schema for table 'stock_quotes':
#   column_name   column_type null   key default extra
# 0      symbol       VARCHAR  YES  None    None  None
# 1        date  TIMESTAMP_MS  YES  None    None  None
# 2        open        DOUBLE  YES  None    None  None
# 3         low        DOUBLE  YES  None    None  None
# 4        high        DOUBLE  YES  None    None  None
# 5       close        DOUBLE  YES  None    None  None
# 6    adjClose        DOUBLE  YES  None    None  None
# 7      volume        BIGINT  YES  None    None  None
# Row count: 12,556,103
#
# 📋 Schema for table 'stock_tickers':
#   column_name column_type null   key default extra
# 0      symbol     VARCHAR  YES  None    None  None
# Row count: 11,895

# %%
# Preview data from each table
for table_name in tables_df['name'].tolist():
    print(f"\n📊 Sample data from '{table_name}':")
    sample_df = duck_conn.execute(f"SELECT * FROM {table_name} LIMIT 5").fetchdf()
    display(sample_df)
# Out:
# 📊 Sample data from 'exchanges':
#   exchange                            name               countryName  \
# 0     AMEX    New York Stock Exchange Arca  United States of America
# 1      BUE     Buenos Aires Stock Exchange                 Argentina
# 2      BVC         Colombia Stock Exchange                  Colombia
# 3     CBOE  Chicago Board Options Exchange  United States of America
# 4      CNQ    Canadian Securities Exchange                    Canada
#
#   countryCode symbolSuffix      delay
# 0          US          N/A  Real-time
# 1          AR          .BA     20 min
# 2          CO          .CL     15 min
# 3          US          N/A  Real-time
# 4          CA          .CN  Real-time
# 📊 Sample data from 'index_list':
#    symbol                              name exchange currency
# 0   ^TTIN  S&P/TSX Capped Industrials Index      TSX      CAD
# 1    ^NYA                    NYSE Composite     NYSE      USD
# 2    ^XAX     NYSE American Composite Index     NYSE      USD
# 3  ^NYITR      NYSE International 100 Index     NYSE      USD
# 4    ^DJU         Dow Jones Utility Average   NASDAQ      USD
# 📊 Sample data from 'index_quotes':
#     symbol       date       price     volume
# 0  TX60.TS 2020-11-03  948.200012   94504821
# 1  TX60.TS 2020-11-04  952.299988  179295563
# 2  TX60.TS 2020-11-05  968.520020  127428692
# 3  TX60.TS 2020-11-06  966.869995  118405024
# 4  TX60.TS 2020-11-09  980.429993  246182781
# 📊 Sample data from 'risk_premium':
#       country      continent  countryRiskPremium  totalEquityRiskPremium
# 0       Haiti  North America               16.02                   20.35
# 1   Greenland  North America                1.12                    5.45
# 2     Uruguay  South America                2.13                    6.46
# 3  Montserrat  North America                2.93                    7.26
# 4    Barbados  North America                8.68                   13.01
# 📊 Sample data from 'stock_metrics':
#   symbol       date  fiscalYear period reportedCurrency     marketCap  \
# 0  AACQU 2025-03-31        2025     Q1              USD  9.745121e+07
# 1  AACQU 2024-12-31        2024     Q4              USD  1.843924e+08
# 2  AACQU 2024-09-30        2024     Q3              USD  2.208169e+08
# 3  AACQU 2024-06-30        2024     Q2              USD  1.191084e+08
# 4  AACQU 2024-03-31        2024     Q1              USD  7.220509e+07
#
#    enterpriseValue  evToSales  evToOperatingCashFlow  evToFreeCashFlow  ...  \
# 0     6.118021e+07  11.267074              -7.249699         -3.964246  ...
# 1     1.377684e+08  14.939101             -24.140247        -14.436591  ...
# 2     1.741719e+08  21.235300             -12.972734        -10.907561  ...
# 3     7.653443e+07  10.882188              -5.115254         -4.906682  ...
# 4     9.640090e+06   1.412467              -0.576044         -0.516231  ...
#
#    operatingCashFlowPerShare  capexPerShare  freeCashFlowPerShare  \
# 0                  -0.057466       0.047626             -0.105092
# 1                  -0.039616       0.026628             -0.066245
# 2                  -0.093634       0.017728             -0.111362
# 3                  -0.104626       0.004447             -0.109074
# 4                  -0.117994       0.013671             -0.131666
#
#    netIncomePerEBT  ebtPerEbit  priceToFairValue  debtToMarketCap  \
# 0         1.002236    0.808693          0.309754         0.074191
# 1         1.020066    0.818070          0.544951         0.029839
# 2         1.006323    2.119640          0.615336         0.024917
# 3         1.002777    1.065071          0.304907         0.076124
# 4         1.008554    0.766517          0.176893         0.121349
#
#    effectiveTaxRate  enterpriseValueMultiple  dividendPerShare
# 0         -0.002236                -2.590187               0.0
# 1         -0.020066               -13.210125               0.0
# 2         -0.006323                -5.197300               0.0
# 3         -0.002777                -4.668726               0.0
# 4         -0.008554                -0.859495               0.0
#
# [5 rows x 107 columns]
# 📊 Sample data from 'stock_profiles':
#      marketCap     ipoDate                       ceo      cusip   volume  \
# 0  10695127780  2021-02-10  Domenic J. Dell'Osso Jr.  165167735  2992655
# 1   8652631527  2014-11-05            John C. Malone  530307305    22997
# 2  60807002560  2010-01-05            Thomas Schafer       None      100
# 3   9477156427  2009-09-29        Mikael Staffas MBA       None      135
# 4   2491479594  2001-06-27     Daniel Llewellyn Rees       None       90
#
#                    sector                                              image  \
# 0                  Energy  https://images.financialmodelingprep.com/symbo...
# 1  Communication Services  https://images.financialmodelingprep.com/symbo...
# 2       Consumer Cyclical  https://images.financialmodelingprep.com/symbo...
# 3         Basic Materials  https://images.financialmodelingprep.com/symbo...
# 4      Financial Services  https://images.financialmodelingprep.com/symbo...
#
#                      address  price                    companyName  ...  \
# 0  6100 North Western Avenue  81.46  Chesapeake Energy Corporation  ...
# 1    12300 Liberty Boulevard  60.28  Liberty Broadband Corporation  ...
# 2            Berliner Ring 2    NaN                  Volkswagen AG  ...
# 3     Klarabergsviadukten 90  34.65              Boliden AB (publ)  ...
# 4       33 City Centre Drive    NaN                    goeasy Ltd.  ...
#
#   defaultImage           city currency                           website  \
# 0        false  Oklahoma City      USD               https://www.chk.com
# 1        false      Englewood      USD  https://www.libertybroadband.com
# 2        false      Wolfsburg      USD      https://www.volkswagenag.com
# 3         true      Stockholm      USD           https://www.boliden.com
# 4        false    Mississauga      USD            https://www.goeasy.com
#
#        zip      exchangeFullName  symbol changePercentage  fullTimeEmployees  \
# 0    73118  NASDAQ Global Select     CHK         -0.96050               1000
# 1    80112  NASDAQ Global Select   LBRDK         -0.42947               1900
# 2    38440             Other OTC   VLKAF          1.94554             639608
# 3   101 20             Other OTC   BOLIF          0.00000               6153
# 4  L5B 2N5             Other OTC   EHMEF          2.90817               2600
#
#                              industry
# 0  Oil & Gas Exploration & Production
# 1         Telecommunications Services
# 2                Auto - Manufacturers
# 3                Industrial Materials
# 4         Financial - Credit Services
#
# [5 rows x 36 columns]
# 📊 Sample data from 'stock_quotes':
#        symbol       date        open         low        high       close  \
# 0  0P00016G44 2020-12-24   10.230000   10.230000   10.230000   10.230000
# 1           A 2020-12-24  117.040000  116.840000  118.370000  117.310000
# 2          AA 2020-12-24   22.340000   21.810000   22.340000   21.960000
# 3       AAALF 2020-12-24   20.775801   20.775801   20.775801   20.775801
# 4       AAALY 2020-12-24   19.300000   19.300000   19.300000   19.300000
#
#      adjClose   volume
# 0   10.230000        0
# 1  113.620000   733600
# 2   21.100000  1075501
# 3   18.550209        0
# 4   17.170000        0
# 📊 Sample data from 'stock_tickers':
#        symbol
# 0  0P00016G44
# 1           A
# 2          AA
# 3       AAALF
# 4       AAALY

# %% [markdown]
# ## 🔌 Connect to Snowflake
#
# We'll connect using Snowflake's compute engine for distributed processing.
#
# > ⚠️ **Security Note:** Never commit credentials to version control. Use environment variables or secret managers.

# %%
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Build connection parameters from environment variables
connection_parameters = {
    "account": os.getenv("SNOWFLAKE_ACCOUNT"),
    "user": os.getenv("SNOWFLAKE_USER"),
    "password": os.getenv("SNOWFLAKE_PASSWORD"),
    "role": os.getenv("SNOWFLAKE_ROLE"),
    "warehouse": os.getenv("SNOWFLAKE_WAREHOUSE")
}

# Create a session
session = Session.builder.configs(connection_parameters).create()
print(f"❄️ Connected to Snowflake account: {session.get_current_account()}")
print(f"Current role: {session.get_current_role()}")
# Out:
# ❄️ Connected to Snowflake account: "OWVFCQY-OUB97142"
# Current role: "ACCOUNTADMIN"

# %% [markdown]
# ### Initialize Root API Object
#
# The `Root` object is the entry point for Snowflake's Python API.

# %%
# Create root object
root = Root(session)
print("Root API object created successfully")
# Out:
# Root API object created successfully

# %% [markdown]
# ### 🔐 Create Lab Role (RBAC)
#
# Create a dedicated role following the **principle of least privilege**.

# %%
# Create lab role using Python API
stocks_lab_role = Role(name="stocks_lab_role")
root.roles.create(stocks_lab_role, mode=CreateMode.if_not_exists)
print("Role 'stocks_lab_role' created successfully")

# Grant role to SYSADMIN
session.sql("GRANT ROLE stocks_lab_role TO ROLE SYSADMIN").collect()

# Grant necessary privileges to role
session.sql("GRANT CREATE WAREHOUSE ON ACCOUNT TO ROLE stocks_lab_role").collect()
session.sql("GRANT CREATE DATABASE ON ACCOUNT TO ROLE stocks_lab_role").collect()

print("Privileges granted to stocks_lab_role")
# Out:
# Role 'stocks_lab_role' created successfully
# Privileges granted to stocks_lab_role

# %% [markdown]
# ### Switch to Lab Role

# %%
session.use_role("stocks_lab_role")
print(f"Switched to role: {session.get_current_role()}")
# Out:
# Switched to role: "STOCKS_LAB_ROLE"

# %% [markdown]
# ---
# # Part 1: Define Data Objects 📐
#
# Create the foundational infrastructure:
# - Database and schemas
# - Compute warehouse
# - Raw data tables (matching DuckDB schema)

# %% [markdown]
# ### 🗄️ Create Database

# %%
# Create database
database_name = "stocks_db"
new_database = Database(name=database_name)
root.databases.create(new_database, mode=CreateMode.or_replace)

print(f"Database '{database_name}' created successfully")

# Set database context
session.use_database(database_name)
print(f"Session is now using database: {session.get_current_database()}")
# Out:
# Database 'stocks_db' created successfully
# Session is now using database: "STOCKS_DB"

# %% [markdown]
# ### 📁 Create Schemas
#
# | Schema | Purpose |
# |--------|---------|
# | `raw` | Source data from DuckDB |
# | `analytics` | Transformed, business-ready data |

# %%
# Get database reference
db = root.databases[database_name]

# Create raw schema
raw_schema = Schema(name="raw")
db.schemas.create(raw_schema, mode=CreateMode.or_replace)
print("Schema 'raw' created successfully")

# Create analytics schema
analytics_schema = Schema(name="analytics")
db.schemas.create(analytics_schema, mode=CreateMode.or_replace)
print("Schema 'analytics' created successfully")
# Out:
# Schema 'raw' created successfully
# Schema 'analytics' created successfully

# %% [markdown]
# ### ⚡ Create Compute Warehouse

# %%
# Create compute resource
virtual_warehouse_name = "stocks_lab_wh"

new_warehouse = Warehouse(
    name=virtual_warehouse_name,
    warehouse_size="MEDIUM"
)

root.warehouses.create(new_warehouse, mode=CreateMode.or_replace)
print(f"Warehouse '{virtual_warehouse_name}' created successfully")

# Grant usage on warehouse to stocks_lab_role
root.roles["stocks_lab_role"].grant_privileges(
    privileges=["USAGE"],
    securable_type="WAREHOUSE",
    securable=Securable(name=virtual_warehouse_name)
)
print(f"Granted USAGE on warehouse to stocks_lab_role")

# Use the warehouse
session.use_warehouse(virtual_warehouse_name)
print(f"Using virtual warehouse: {session.get_current_warehouse()}")
# Out:
# Warehouse 'stocks_lab_wh' created successfully
# Granted USAGE on warehouse to stocks_lab_role
# Using virtual warehouse: "STOCKS_LAB_WH"

# %% [markdown]
# ### 📊 Create Raw Tables
#
# We'll dynamically create tables in Snowflake based on the DuckDB schema.

# %%
# Helper function to map DuckDB types to Snowflake types
def duckdb_to_snowflake_type(duckdb_type: str, max_length: int = None) -> str:
    """Map DuckDB data types to Snowflake data types.
    
    Args:
        duckdb_type: The DuckDB column type
        max_length: Optional max string length for VARCHAR optimization
    """
    type_mapping = {
        'BIGINT': 'NUMBER(38,0)',
        'INTEGER': 'NUMBER(38,0)',
        'SMALLINT': 'NUMBER(38,0)',
        'TINYINT': 'NUMBER(38,0)',
        'DOUBLE': 'FLOAT',
        'FLOAT': 'FLOAT',
        'REAL': 'FLOAT',
        'DECIMAL': 'NUMBER(38,10)',
        'DATE': 'DATE',
        'TIMESTAMP': 'TIMESTAMP_NTZ(9)',
        'TIMESTAMP WITH TIME ZONE': 'TIMESTAMP_TZ(9)',
        'TIME': 'TIME(9)',
        'BOOLEAN': 'BOOLEAN',
        'BLOB': 'BINARY',
        'HUGEINT': 'NUMBER(38,0)',
    }
    
    duckdb_type_upper = duckdb_type.upper()
    
    # Handle VARCHAR/TEXT/STRING types with optimized sizing
    if any(t in duckdb_type_upper for t in ['VARCHAR', 'TEXT', 'STRING']):
        if max_length is not None and max_length > 0:
            # Add 20% buffer and round up to nearest power of 2 or nice number
            buffer_size = max(int(max_length * 1.2), max_length + 10)
            # Round to nice sizes: 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, etc.
            nice_sizes = [16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536]
            for size in nice_sizes:
                if buffer_size <= size:
                    return f'VARCHAR({size})'
            # If larger than our nice sizes, use the buffered value rounded up
            return f'VARCHAR({buffer_size})'
        else:
            # No data or empty strings - use minimal default
            return 'VARCHAR(256)'
    
    # Check for exact match
    if duckdb_type_upper in type_mapping:
        return type_mapping[duckdb_type_upper]
    
    # Check for partial matches (e.g., DECIMAL(10,2))
    for duck_type, snow_type in type_mapping.items():
        if duckdb_type_upper.startswith(duck_type):
            return snow_type
    
    # Default fallback
    return 'VARCHAR(256)'


def get_varchar_max_lengths(conn, table_name: str) -> dict:
    """Query DuckDB to get max string lengths for VARCHAR columns."""
    # Get schema info
    schema_df = conn.execute(f"DESCRIBE {table_name}").fetchdf()
    
    max_lengths = {}
    varchar_cols = []
    
    for _, row in schema_df.iterrows():
        col_name = row['column_name']
        col_type = row['column_type'].upper()
        
        if any(t in col_type for t in ['VARCHAR', 'TEXT', 'STRING']):
            varchar_cols.append(col_name)
    
    if varchar_cols:
        # Build a single query to get max lengths for all VARCHAR columns
        length_expressions = [f'MAX(LENGTH("{col}")) as "{col}"' for col in varchar_cols]
        query = f"SELECT {', '.join(length_expressions)} FROM {table_name}"
        result = conn.execute(query).fetchone()
        
        for i, col in enumerate(varchar_cols):
            max_lengths[col] = result[i] if result[i] is not None else 0
    
    return max_lengths

print("✅ Type mapping function with VARCHAR optimization created")
# Out:
# ✅ Type mapping function with VARCHAR optimization created

# %%
# Get schema reference
raw_schema_ref = db.schemas["raw"]

# Get list of tables from DuckDB
duckdb_tables = duck_conn.execute("SHOW TABLES").fetchdf()['name'].tolist()

print("📊 Creating tables with optimized VARCHAR sizes...\n")

for table_name in duckdb_tables:
    print(f"📋 Creating table '{table_name}' in Snowflake...")
    
    # Get schema from DuckDB
    schema_df = duck_conn.execute(f"DESCRIBE {table_name}").fetchdf()
    
    # Get max lengths for VARCHAR columns
    max_lengths = get_varchar_max_lengths(duck_conn, table_name)
    if max_lengths:
        print(f"   VARCHAR max lengths: {max_lengths}")
    
    # Build Snowflake column definitions with optimized types
    columns = []
    for _, row in schema_df.iterrows():
        col_name = row['column_name']
        duckdb_type = row['column_type']
        max_len = max_lengths.get(col_name)
        col_type = duckdb_to_snowflake_type(duckdb_type, max_len)
        
        columns.append(TableColumn(name=col_name, datatype=col_type))
        print(f"   - {col_name}: {duckdb_type} -> {col_type}")
    
    # Create the table
    snowflake_table = Table(name=table_name, columns=columns)
    raw_schema_ref.tables.create(snowflake_table, mode=CreateMode.or_replace)
    print(f"   ✅ Table '{table_name}' created\n")
# Out:
# 📊 Creating tables with optimized VARCHAR sizes...
#
# 📋 Creating table 'exchanges' in Snowflake...
#    VARCHAR max lengths: {'exchange': 6, 'name': 31, 'countryName': 24, 'countryCode': 2, 'symbolSuffix': 3, 'delay': 9}
#    - exchange: VARCHAR -> VARCHAR(16)
#    - name: VARCHAR -> VARCHAR(64)
#    - countryName: VARCHAR -> VARCHAR(64)
#    - countryCode: VARCHAR -> VARCHAR(16)
#    - symbolSuffix: VARCHAR -> VARCHAR(16)
#    - delay: VARCHAR -> VARCHAR(32)
#    ✅ Table 'exchanges' created
#
# 📋 Creating table 'index_list' in Snowflake...
#    VARCHAR max lengths: {'symbol': 9, 'name': 52, 'exchange': 6, 'currency': 3}
#    - symbol: VARCHAR -> VARCHAR(32)
#    - name: VARCHAR -> VARCHAR(64)
#    - exchange: VARCHAR -> VARCHAR(16)
#    - currency: VARCHAR -> VARCHAR(16)
#    ✅ Table 'index_list' created
#
# 📋 Creating table 'index_quotes' in Snowflake...
#    VARCHAR max lengths: {'symbol': 9}
#    - symbol: VARCHAR -> VARCHAR(32)
#    - date: DATE -> DATE
#    - price: DOUBLE -> FLOAT
#    - volume: BIGINT -> NUMBER(38,0)
#    ✅ Table 'index_quotes' created
#
# 📋 Creating table 'risk_premium' in Snowflake...
#    VARCHAR max lengths: {'country': 22, 'continent': 13}
#    - country: VARCHAR -> VARCHAR(32)
#    - continent: VARCHAR -> VARCHAR(32)
#    - countryRiskPremium: DOUBLE -> FLOAT
#    - totalEquityRiskPremium: DOUBLE -> FLOAT
#    ✅ Table 'risk_premium' created
#
# 📋 Creating table 'stock_metrics' in Snowflake...
#    VARCHAR max lengths: {'symbol': 13, 'period': 2, 'reportedCurrency': 3, 'reportedCurrency_ratio': 3}
#    - symbol: VARCHAR -> VARCHAR(32)
#    - date: TIMESTAMP_MS -> TIMESTAMP_NTZ(9)
#    - fiscalYear: BIGINT -> NUMBER(38,0)
#    - period: VARCHAR -> VARCHAR(16)
#    - reportedCurrency: VARCHAR -> VARCHAR(16)
#    - marketCap: DOUBLE -> FLOAT
#    - enterpriseValue: DOUBLE -> FLOAT
#    - evToSales: DOUBLE -> FLOAT
#    - evToOperatingCashFlow: DOUBLE -> FLOAT
#    - evToFreeCashFlow: DOUBLE -> FLOAT
#    - evToEBITDA: DOUBLE -> FLOAT
#    - netDebtToEBITDA: DOUBLE -> FLOAT
#    - currentRatio: DOUBLE -> FLOAT
#    - incomeQuality: DOUBLE -> FLOAT
#    - grahamNumber: DOUBLE -> FLOAT
#    - grahamNetNet: DOUBLE -> FLOAT
#    - taxBurden: DOUBLE -> FLOAT
#    - interestBurden: DOUBLE -> FLOAT
#    - workingCapital: DOUBLE -> FLOAT
#    - investedCapital: DOUBLE -> FLOAT
#    - returnOnAssets: DOUBLE -> FLOAT
#    - operatingReturnOnAssets: DOUBLE -> FLOAT
#    - returnOnTangibleAssets: DOUBLE -> FLOAT
#    - returnOnEquity: DOUBLE -> FLOAT
#    - returnOnInvestedCapital: DOUBLE -> FLOAT
#    - returnOnCapitalEmployed: DOUBLE -> FLOAT
#    - earningsYield: DOUBLE -> FLOAT
#    - freeCashFlowYield: DOUBLE -> FLOAT
#    - capexToOperatingCashFlow: DOUBLE -> FLOAT
#    - capexToDepreciation: DOUBLE -> FLOAT
#    - capexToRevenue: DOUBLE -> FLOAT
#    - salesGeneralAndAdministrativeToRevenue: DOUBLE -> FLOAT
#    - researchAndDevelopementToRevenue: DOUBLE -> FLOAT
#    - stockBasedCompensationToRevenue: DOUBLE -> FLOAT
#    - intangiblesToTotalAssets: DOUBLE -> FLOAT
#    - averageReceivables: DOUBLE -> FLOAT
#    - averagePayables: DOUBLE -> FLOAT
#    - averageInventory: DOUBLE -> FLOAT
#    - daysOfSalesOutstanding: DOUBLE -> FLOAT
#    - daysOfPayablesOutstanding: DOUBLE -> FLOAT
#    - daysOfInventoryOutstanding: DOUBLE -> FLOAT
#    - operatingCycle: DOUBLE -> FLOAT
#    - cashConversionCycle: DOUBLE -> FLOAT
#    - freeCashFlowToEquity: DOUBLE -> FLOAT
#    - freeCashFlowToFirm: DOUBLE -> FLOAT
#    - tangibleAssetValue: DOUBLE -> FLOAT
#    - netCurrentAssetValue: DOUBLE -> FLOAT
#    - reportedCurrency_ratio: VARCHAR -> VARCHAR(16)
#    - grossProfitMargin: DOUBLE -> FLOAT
#    - ebitMargin: DOUBLE -> FLOAT
#    - ebitdaMargin: DOUBLE -> FLOAT
#    - operatingProfitMargin: DOUBLE -> FLOAT
#    - pretaxProfitMargin: DOUBLE -> FLOAT
#    - continuousOperationsProfitMargin: DOUBLE -> FLOAT
#    - netProfitMargin: DOUBLE -> FLOAT
#    - bottomLineProfitMargin: DOUBLE -> FLOAT
#    - receivablesTurnover: DOUBLE -> FLOAT
#    - payablesTurnover: DOUBLE -> FLOAT
#    - inventoryTurnover: DOUBLE -> FLOAT
#    - fixedAssetTurnover: DOUBLE -> FLOAT
#    - assetTurnover: DOUBLE -> FLOAT
#    - currentRatio_ratio: DOUBLE -> FLOAT
#    - quickRatio: DOUBLE -> FLOAT
#    - solvencyRatio: DOUBLE -> FLOAT
#    - cashRatio: DOUBLE -> FLOAT
#    - priceToEarningsRatio: DOUBLE -> FLOAT
#    - priceToEarningsGrowthRatio: DOUBLE -> FLOAT
#    - forwardPriceToEarningsGrowthRatio: DOUBLE -> FLOAT
#    - priceToBookRatio: DOUBLE -> FLOAT
#    - priceToSalesRatio: DOUBLE -> FLOAT
#    - priceToFreeCashFlowRatio: DOUBLE -> FLOAT
#    - priceToOperatingCashFlowRatio: DOUBLE -> FLOAT
#    - debtToAssetsRatio: DOUBLE -> FLOAT
#    - debtToEquityRatio: DOUBLE -> FLOAT
#    - debtToCapitalRatio: DOUBLE -> FLOAT
#    - longTermDebtToCapitalRatio: DOUBLE -> FLOAT
#    - financialLeverageRatio: DOUBLE -> FLOAT
#    - workingCapitalTurnoverRatio: DOUBLE -> FLOAT
#    - operatingCashFlowRatio: DOUBLE -> FLOAT
#    - operatingCashFlowSalesRatio: DOUBLE -> FLOAT
#    - freeCashFlowOperatingCashFlowRatio: DOUBLE -> FLOAT
#    - debtServiceCoverageRatio: DOUBLE -> FLOAT
#    - interestCoverageRatio: DOUBLE -> FLOAT
#    - shortTermOperatingCashFlowCoverageRatio: DOUBLE -> FLOAT
#    - operatingCashFlowCoverageRatio: DOUBLE -> FLOAT
#    - capitalExpenditureCoverageRatio: DOUBLE -> FLOAT
#    - dividendPaidAndCapexCoverageRatio: DOUBLE -> FLOAT
#    - dividendPayoutRatio: DOUBLE -> FLOAT
#    - dividendYield: DOUBLE -> FLOAT
#    - dividendYieldPercentage: DOUBLE -> FLOAT
#    - revenuePerShare: DOUBLE -> FLOAT
#    - netIncomePerShare: DOUBLE -> FLOAT
#    - interestDebtPerShare: DOUBLE -> FLOAT
#    - cashPerShare: DOUBLE -> FLOAT
#    - bookValuePerShare: DOUBLE -> FLOAT
#    - tangibleBookValuePerShare: DOUBLE -> FLOAT
#    - shareholdersEquityPerShare: DOUBLE -> FLOAT
#    - operatingCashFlowPerShare: DOUBLE -> FLOAT
#    - capexPerShare: DOUBLE -> FLOAT
#    - freeCashFlowPerShare: DOUBLE -> FLOAT
#    - netIncomePerEBT: DOUBLE -> FLOAT
#    - ebtPerEbit: DOUBLE -> FLOAT
#    - priceToFairValue: DOUBLE -> FLOAT
#    - debtToMarketCap: DOUBLE -> FLOAT
#    - effectiveTaxRate: DOUBLE -> FLOAT
#    - enterpriseValueMultiple: DOUBLE -> FLOAT
#    - dividendPerShare: DOUBLE -> FLOAT
#    ✅ Table 'stock_metrics' created
#
# 📋 Creating table 'stock_profiles' in Snowflake...
#    VARCHAR max lengths: {'ipoDate': 10, 'ceo': 61, 'cusip': 9, 'sector': 22, 'image': 65, 'address': 123, 'companyName': 94, 'cik': 10, 'range': 19, 'isFund': 5, 'phone': 18, 'isin': 12, 'isEtf': 5, 'exchange': 6, 'isActivelyTrading': 5, 'state': 3, 'country': 2, 'isAdr': 5, 'description': 5415, 'defaultImage': 5, 'city': 25, 'currency': 3, 'website': 162, 'zip': 10, 'exchangeFullName': 31, 'symbol': 13, 'fullTimeEmployees': 7, 'industry': 43}
#    - marketCap: BIGINT -> NUMBER(38,0)
#    - ipoDate: VARCHAR -> VARCHAR(32)
#    - ceo: VARCHAR -> VARCHAR(128)
#    - cusip: VARCHAR -> VARCHAR(32)
#    - volume: BIGINT -> NUMBER(38,0)
#    - sector: VARCHAR -> VARCHAR(32)
#    - image: VARCHAR -> VARCHAR(128)
#    - address: VARCHAR -> VARCHAR(256)
#    - price: DOUBLE -> FLOAT
#    - companyName: VARCHAR -> VARCHAR(128)
#    - cik: VARCHAR -> VARCHAR(32)
#    - beta: DOUBLE -> FLOAT
#    - range: VARCHAR -> VARCHAR(32)
#    - isFund: VARCHAR -> VARCHAR(16)
#    - phone: VARCHAR -> VARCHAR(32)
#    - isin: VARCHAR -> VARCHAR(32)
#    - lastDividend: DOUBLE -> FLOAT
#    - isEtf: VARCHAR -> VARCHAR(16)
#    - averageVolume: DOUBLE -> FLOAT
#    - exchange: VARCHAR -> VARCHAR(16)
#    - isActivelyTrading: VARCHAR -> VARCHAR(16)
#    - state: VARCHAR -> VARCHAR(16)
#    - change: DOUBLE -> FLOAT
#    - country: VARCHAR -> VARCHAR(16)
#    - isAdr: VARCHAR -> VARCHAR(16)
#    - description: VARCHAR -> VARCHAR(8192)
#    - defaultImage: VARCHAR -> VARCHAR(16)
#    - city: VARCHAR -> VARCHAR(64)
#    - currency: VARCHAR -> VARCHAR(16)
#    - website: VARCHAR -> VARCHAR(256)
#    - zip: VARCHAR -> VARCHAR(32)
#    - exchangeFullName: VARCHAR -> VARCHAR(64)
#    - symbol: VARCHAR -> VARCHAR(32)
#    - changePercentage: DOUBLE -> FLOAT
#    - fullTimeEmployees: VARCHAR -> VARCHAR(32)
#    - industry: VARCHAR -> VARCHAR(64)
#    ✅ Table 'stock_profiles' created
#
# 📋 Creating table 'stock_quotes' in Snowflake...
#    VARCHAR max lengths: {'symbol': 13}
#    - symbol: VARCHAR -> VARCHAR(32)
#    - date: TIMESTAMP_MS -> TIMESTAMP_NTZ(9)
#    - open: DOUBLE -> FLOAT
#    - low: DOUBLE -> FLOAT
#    - high: DOUBLE -> FLOAT
#    - close: DOUBLE -> FLOAT
#    - adjClose: DOUBLE -> FLOAT
#    - volume: BIGINT -> NUMBER(38,0)
#    ✅ Table 'stock_quotes' created
#
# 📋 Creating table 'stock_tickers' in Snowflake...
#    VARCHAR max lengths: {'symbol': 13}
#    - symbol: VARCHAR -> VARCHAR(32)
#    ✅ Table 'stock_tickers' created

# %% [markdown]
# ---
# # Part 2: Ingest Data 📥
#
# Load data from DuckDB into Snowflake using bulk upload.
#
# > 💡 **Pattern:** DuckDB → pandas → `write_pandas()` (bulk upload via Parquet staging)
#
# ### ⚡ Performance Optimizations:
# | Optimization | Benefit |
# |--------------|---------|
# | **Optimized VARCHAR sizes** | Reduced storage footprint based on actual data |
# | **`write_pandas()`** | Bulk upload via internal Parquet staging (10-100x faster than row-by-row) |
# | **Pre-created tables** | Correct data types (DATE, NUMBER, etc.) preserved |

# %%
def load_table_to_snowflake(table_name: str) -> tuple[str, int, float]:
    """Load a single table from DuckDB to Snowflake using bulk upload."""
    start_time = time.perf_counter()
    
    # DuckDB -> pandas
    pandas_df = duck_conn.execute(f"SELECT * FROM {table_name}").fetchdf()
    row_count = len(pandas_df)
    
    if row_count == 0:
        print(f"  ⚠️ Table '{table_name}' is empty, skipping...")
        return table_name, 0, time.perf_counter() - start_time
    
    # Uppercase column names for Snowflake
    pandas_df.columns = [col.upper() for col in pandas_df.columns]
    
    # Convert date/datetime columns to ISO format strings
    # Snowflake auto-casts to DATE/TIMESTAMP based on pre-defined schema
    for col in pandas_df.columns:
        dtype_str = str(pandas_df[col].dtype)
        
        if 'datetime64' in dtype_str:
            pandas_df[col] = pandas_df[col].dt.strftime('%Y-%m-%d %H:%M:%S')
        elif pandas_df[col].dtype == 'object' and len(pandas_df[col].dropna()) > 0:
            first_val = pandas_df[col].dropna().iloc[0]
            if isinstance(first_val, date) and not isinstance(first_val, datetime):
                pandas_df[col] = pandas_df[col].apply(lambda x: x.strftime('%Y-%m-%d') if x is not None else None)
            elif isinstance(first_val, datetime):
                pandas_df[col] = pandas_df[col].apply(lambda x: x.strftime('%Y-%m-%d %H:%M:%S') if x is not None else None)
    
    # Bulk upload using pre-created tables with optimized schema
    session.write_pandas(
        pandas_df,
        table_name=table_name.upper(),
        database="STOCKS_DB",
        schema="RAW",
        auto_create_table=False,
        overwrite=True,
        quote_identifiers=False
    )
    
    elapsed = time.perf_counter() - start_time
    return table_name, row_count, elapsed


# Load all tables
print("🚀 Starting data ingestion...\n")
total_start = time.perf_counter()

results = []
for table_name in duckdb_tables:
    name, row_count, elapsed = load_table_to_snowflake(table_name)
    results.append((name, row_count, elapsed))
    print(f"✅ {name}: {row_count:,} rows in {elapsed:.2f}s")

total_elapsed = time.perf_counter() - total_start
total_rows = sum(r[1] for r in results)

print(f"\n📊 Summary: Loaded {total_rows:,} total rows in {total_elapsed:.2f}s")
print(f"   Throughput: {total_rows/total_elapsed:,.0f} rows/second")
# Out:
# 🚀 Starting data ingestion...
#
# ✅ exchanges: 14 rows in 3.43s
# ✅ index_list: 36 rows in 2.85s
# ✅ index_quotes: 111,946 rows in 6.97s
# ✅ risk_premium: 44 rows in 3.03s
# ✅ stock_metrics: 129,384 rows in 103.13s
# ✅ stock_profiles: 11,895 rows in 10.46s
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ✅ stock_quotes: 12,556,103 rows in 325.48s
# ✅ stock_tickers: 11,895 rows in 3.51s
#
# 📊 Summary: Loaded 12,821,317 total rows in 459.40s
#    Throughput: 27,909 rows/second

# %% [markdown]
# ### ✅ Verify Data Loading
#
# Confirm data was loaded correctly by checking row counts.

# %%
# Verify row counts match
print("📊 Data Verification Summary:\n")
print(f"{'Table':<30} {'DuckDB Rows':>15} {'Snowflake Rows':>15} {'Match':>10}")
print("-" * 75)

for table_name in duckdb_tables:
    # DuckDB count
    duckdb_count = duck_conn.execute(f"SELECT COUNT(*) FROM {table_name}").fetchone()[0]
    
    # Snowflake count
    snowflake_count = session.table(f"stocks_db.raw.{table_name}").count()
    
    # Check match
    match = "✅" if duckdb_count == snowflake_count else "❌"
    
    print(f"{table_name:<30} {duckdb_count:>15,} {snowflake_count:>15,} {match:>10}")
# Out:
# 📊 Data Verification Summary:
#
# Table                              DuckDB Rows  Snowflake Rows      Match
# ---------------------------------------------------------------------------
# exchanges                                   14              14          ✅
# index_list                                  36              36          ✅
# index_quotes                           111,946         111,946          ✅
# risk_premium                                44              44          ✅
# stock_metrics                          129,384         129,384          ✅
# stock_profiles                          11,895          11,895          ✅
# stock_quotes                        12,556,103      12,556,103          ✅
# stock_tickers                           11,895          11,895          ✅

# %%
# Preview data in Snowflake
for table_name in duckdb_tables:
    print(f"\n📊 Sample data from 'stocks_db.raw.{table_name}':")
    session.table(f"stocks_db.raw.{table_name}").limit(5).show()
# Out:
# 📊 Sample data from 'stocks_db.raw.exchanges':
# -----------------------------------------------------------------------------------------------------------------------
# |"EXCHANGE"  |"NAME"                          |"COUNTRYNAME"             |"COUNTRYCODE"  |"SYMBOLSUFFIX"  |"DELAY"    |
# -----------------------------------------------------------------------------------------------------------------------
# |AMEX        |New York Stock Exchange Arca    |United States of America  |US             |N/A             |Real-time  |
# |BUE         |Buenos Aires Stock Exchange     |Argentina                 |AR             |.BA             |20 min     |
# |BVC         |Colombia Stock Exchange         |Colombia                  |CO             |.CL             |15 min     |
# |CBOE        |Chicago Board Options Exchange  |United States of America  |US             |N/A             |Real-time  |
# |CNQ         |Canadian Securities Exchange    |Canada                    |CA             |.CN             |Real-time  |
# -----------------------------------------------------------------------------------------------------------------------
#
#
# 📊 Sample data from 'stocks_db.raw.index_list':
# -------------------------------------------------------------------------
# |"SYMBOL"  |"NAME"                            |"EXCHANGE"  |"CURRENCY"  |
# -------------------------------------------------------------------------
# |^TTIN     |S&P/TSX Capped Industrials Index  |TSX         |CAD         |
# |^NYA      |NYSE Composite                    |NYSE        |USD         |
# |^XAX      |NYSE American Composite Index     |NYSE        |USD         |
# |^NYITR    |NYSE International 100 Index      |NYSE        |USD         |
# |^DJU      |Dow Jones Utility Average         |NASDAQ      |USD         |
# -------------------------------------------------------------------------
#
#
# 📊 Sample data from 'stocks_db.raw.index_quotes':
# --------------------------------------------------
# |"SYMBOL"  |"DATE"      |"PRICE"     |"VOLUME"   |

# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# 📊 Sample data from 'stocks_db.raw.stock_quotes':
# ------------------------------------------------------------------------------------------------------------
# |"SYMBOL"    |"DATE"               |"OPEN"     |"LOW"      |"HIGH"     |"CLOSE"    |"ADJCLOSE"  |"VOLUME"  |
# ------------------------------------------------------------------------------------------------------------
# |0P00016G44  |2020-12-24 00:00:00  |10.23      |10.23      |10.23      |10.23      |10.23       |0         |
# |A           |2020-12-24 00:00:00  |117.04     |116.84     |118.37     |117.31     |113.62      |733600    |
# |AA          |2020-12-24 00:00:00  |22.34      |21.81      |22.34      |21.96      |21.1        |1075501   |
# |AAALF       |2020-12-24 00:00:00  |20.775801  |20.775801  |20.775801  |20.775801  |18.550209   |0         |
# |AAALY       |2020-12-24 00:00:00  |19.3       |19.3       |19.3       |19.3       |17.17       |0         |
# ------------------------------------------------------------------------------------------------------------
#
#
# 📊 Sample data from 'stocks_db.raw.stock_tickers':
# --------------
# |"SYMBOL"    |
# --------------
# |0P00016G44  |
# |A           |
# |AA          |
# |AAALF       |
# |AAALY       |
# --------------

# %% [markdown]
# ---
# # Part 3: Transform Raw Data 🔄
#
# Build transformation pipelines using **Snowflake Dynamic Tables**.
#
# > 💡 **Note:** The transformations below are templates. Customize them based on your actual DuckDB schema!

# %% [markdown]
# ### 💡 What are Dynamic Tables?
#
# | Feature | Benefit |
# |---------|---------|
# | **Automatic Scheduling** | No manual orchestration needed |
# | **Incremental Refresh** | Processes only changed rows |
# | **Dependency Tracking** | Native DAG visualization in UI |

# %% [markdown]
# ## Tier 1: Enrichment Layer
#
# Let's create enriched views of the stock data. The exact transformations depend on your DuckDB schema.

# %%
# First, let's examine what tables we have to work with
print("Available tables in raw schema:")
for table_name in duckdb_tables:
    print(f"\n📋 Table: {table_name}")
    session.table(f"stocks_db.raw.{table_name}").printSchema()
# Out:
# Available tables in raw schema:
#
# 📋 Table: exchanges
# root
#  |-- "EXCHANGE": StringType(16) (nullable = True)
#  |-- "NAME": StringType(64) (nullable = True)
#  |-- "COUNTRYNAME": StringType(64) (nullable = True)
#  |-- "COUNTRYCODE": StringType(16) (nullable = True)
#  |-- "SYMBOLSUFFIX": StringType(16) (nullable = True)
#  |-- "DELAY": StringType(32) (nullable = True)
#
# 📋 Table: index_list
# root
#  |-- "SYMBOL": StringType(32) (nullable = True)
#  |-- "NAME": StringType(64) (nullable = True)
#  |-- "EXCHANGE": StringType(16) (nullable = True)
#  |-- "CURRENCY": StringType(16) (nullable = True)
#
# 📋 Table: index_quotes
# root
#  |-- "SYMBOL": StringType(32) (nullable = True)
#  |-- "DATE": DateType() (nullable = True)
#  |-- "PRICE": DoubleType() (nullable = True)
#  |-- "VOLUME": LongType() (nullable = True)
#
# 📋 Table: risk_premium
# root
#  |-- "COUNTRY": StringType(32) (nullable = True)
#  |-- "CONTINENT": StringType(32) (nullable = True)
#  |-- "COUNTRYRISKPREMIUM": DoubleType() (nullable = True)
#  |-- "TOTALEQUITYRISKPREMIUM": DoubleType() (nullable = True)
#
# 📋 Table: stock_metrics
# root
#  |-- "SYMBOL": StringType(32) (nullable = True)
#  |-- "DATE": TimestampType(timezone=TimestampTimeZone('ntz')) (nullable = True)
#  |-- "FISCALYEAR": LongType() (nullable = True)
#  |-- "PERIOD": StringType(16) (nullable = True)
#  |-- "REPORTEDCURRENCY": StringType(16) (nullable = True)
#  |-- "MARKETCAP": DoubleType() (nullable = True)
#  |-- "ENTERPRISEVALUE": DoubleType() (nullable = True)
#  |-- "EVTOSALES": DoubleType() (nullable = True)
#  |-- "EVTOOPERATINGCASHFLOW": DoubleType() (nullable = True)
#  |-- "EVTOFREECASHFLOW": DoubleType() (nullable = True)
#  |-- "EVTOEBITDA": DoubleType() (nullable = True)
#  |-- "NETDEBTTOEBITDA": DoubleType() (nullable = True)
#  |-- "CURRENTRATIO": DoubleType() (nullable = True)
#  |-- "INCOMEQUALITY": DoubleType() (nullable = True)
#  |-- "GRAHAMNUMBER": DoubleType() (nullable = True)
#  |-- "GRAHAMNETNET": DoubleType() (nullable = True)
#  |-- "TAXBURDEN": DoubleType() (nullable = True)
#  |-- "INTERESTBURDEN": DoubleType() (nullable = True)
#  |-- "WORKINGCAPITAL": DoubleType() (nullable = True)
#  |-- "INVESTEDCAPITAL": DoubleType() (nullable = True)
#  |-- "RETURNONASSETS": DoubleType() (nullable = True)
#  |-- "OPERATINGRETURNONASSETS": DoubleType() (nullable = True)
#  |-- "RETURNONTANGIBLEASSETS": DoubleType() (nullable = True)
#  |-- "RETURNONEQUITY": DoubleType() (nullable = True)
#  |-- "RETURNONINVESTEDCAPITAL": DoubleType() (nullable = True)
#  |-- "RETURNONCAPITALEMPLOYED": DoubleType() (nullable = True)
#  |-- "EARNINGSYIELD": DoubleType() (nullable = True)
#  |-- "FREECASHFLOWYIELD": DoubleType() (nullable = True)
#  |-- "CAPEXTOOPERATINGCASHFLOW": DoubleType() (nullable = True)
#  |-- "CAPEXTODEPRECIATION": DoubleType() (nullable = True)
#  |-- "CAPEXTOREVENUE": DoubleType() (nullable = True)
#  |-- "SALESGENERALANDADMINISTRATIVETOREVENUE": DoubleType() (nullable = True)
#  |-- "RESEARCHANDDEVELOPEMENTTOREVENUE": DoubleType() (nullable = True)
#  |-- "STOCKBASEDCOMPENSATIONTOREVENUE": DoubleType() (nullable = True)
#  |-- "INTANGIBLESTOTOTALASSETS": DoubleType() (nullable = True)
#  |-- "AVERAGERECEIVABLES": DoubleType() (nullable = True)
#  |-- "AVERAGEPAYABLES": DoubleType() (nullable = True)
#  |-- "AVERAGEINVENTORY": DoubleType() (nullable = True)
#  |-- "DAYSOFSALESOUTSTANDING": DoubleType() (nullable = True)
#  |-- "DAYSOFPAYABLESOUTSTANDING": DoubleType() (nullable = True)
#  |-- "DAYSOFINVENTORYOUTSTANDING": DoubleType() (nullable = True)
#  |-- "OPERATINGCYCLE": DoubleType() (nullable = True)
#  |-- "CASHCONVERSIONCYCLE": DoubleType() (nullable = True)
#  |-- "FREECASHFLOWTOEQUITY": DoubleType() (nullable = True)
#  |-- "FREECASHFLOWTOFIRM": DoubleType() (nullable = True)
#  |-- "TANGIBLEASSETVALUE": DoubleType() (nullable = True)
#  |-- "NETCURRENTASSETVALUE": DoubleType() (nullable = True)
#  |-- "REPORTEDCURRENCY_RATIO": StringType(16) (nullable = True)
#  |-- "GROSSPROFITMARGIN": DoubleType() (nullable = True)
#  |-- "EBITMARGIN": DoubleType() (nullable = True)
#  |-- "EBITDAMARGIN": DoubleType() (nullable = True)
#  |-- "OPERATINGPROFITMARGIN": DoubleType() (nullable = True)
#  |-- "PRETAXPROFITMARGIN": DoubleType() (nullable = True)
#  |-- "CONTINUOUSOPERATIONSPROFITMARGIN": DoubleType() (nullable = True)
#  |-- "NETPROFITMARGIN": DoubleType() (nullable = True)
#  |-- "BOTTOMLINEPROFITMARGIN": DoubleType() (nullable = True)
#  |-- "RECEIVABLESTURNOVER": DoubleType() (nullable = True)
#  |-- "PAYABLESTURNOVER": DoubleType() (nullable = True)
#  |-- "INVENTORYTURNOVER": DoubleType() (nullable = True)
#  |-- "FIXEDASSETTURNOVER": DoubleType() (nullable = True)
#  |-- "ASSETTURNOVER": DoubleType() (nullable = True)
#  |-- "CURRENTRATIO_RATIO": DoubleType() (nullable = True)
#  |-- "QUICKRATIO": DoubleType() (nullable = True)
#  |-- "SOLVENCYRATIO": DoubleType() (nullable = True)
#  |-- "CASHRATIO": DoubleType() (nullable = True)
#  |-- "PRICETOEARNINGSRATIO": DoubleType() (nullable = True)
#  |-- "PRICETOEARNINGSGROWTHRATIO": DoubleType() (nullable = True)
#  |-- "FORWARDPRICETOEARNINGSGROWTHRATIO": DoubleType() (nullable = True)
#  |-- "PRICETOBOOKRATIO": DoubleType() (nullable = True)
#  |-- "PRICETOSALESRATIO": DoubleType() (nullable = True)
#  |-- "PRICETOFREECASHFLOWRATIO": DoubleType() (nullable = True)
#  |-- "PRICETOOPERATINGCASHFLOWRATIO": DoubleType() (nullable = True)
#  |-- "DEBTTOASSETSRATIO": DoubleType() (nullable = True)
#  |-- "DEBTTOEQUITYRATIO": DoubleType() (nullable = True)
#  |-- "DEBTTOCAPITALRATIO": DoubleType() (nullable = True)
#  |-- "LONGTERMDEBTTOCAPITALRATIO": DoubleType() (nullable = True)
#  |-- "FINANCIALLEVERAGERATIO": DoubleType() (nullable = True)
#  |-- "WORKINGCAPITALTURNOVERRATIO": DoubleType() (nullable = True)
#  |-- "OPERATINGCASHFLOWRATIO": DoubleType() (nullable = True)
#  |-- "OPERATINGCASHFLOWSALESRATIO": DoubleType() (nullable = True)
#  |-- "FREECASHFLOWOPERATINGCASHFLOWRATIO": DoubleType() (nullable = True)
#  |-- "DEBTSERVICECOVERAGERATIO": DoubleType() (nullable = True)
#  |-- "INTERESTCOVERAGERATIO": DoubleType() (nullable = True)
#  |-- "SHORTTERMOPERATINGCASHFLOWCOVERAGERATIO": DoubleType() (nullable = True)
#  |-- "OPERATINGCASHFLOWCOVERAGERATIO": DoubleType() (nullable = True)
#  |-- "CAPITALEXPENDITURECOVERAGERATIO": DoubleType() (nullable = True)
#  |-- "DIVIDENDPAIDANDCAPEXCOVERAGERATIO": DoubleType() (nullable = True)
#  |-- "DIVIDENDPAYOUTRATIO": DoubleType() (nullable = True)
#  |-- "DIVIDENDYIELD": DoubleType() (nullable = True)
#  |-- "DIVIDENDYIELDPERCENTAGE": DoubleType() (nullable = True)
#  |-- "REVENUEPERSHARE": DoubleType() (nullable = True)
#  |-- "NETINCOMEPERSHARE": DoubleType() (nullable = True)
#  |-- "INTERESTDEBTPERSHARE": DoubleType() (nullable = True)
#  |-- "CASHPERSHARE": DoubleType() (nullable = True)
#  |-- "BOOKVALUEPERSHARE": DoubleType() (nullable = True)
#  |-- "TANGIBLEBOOKVALUEPERSHARE": DoubleType() (nullable = True)
#  |-- "SHAREHOLDERSEQUITYPERSHARE": DoubleType() (nullable = True)
#  |-- "OPERATINGCASHFLOWPERSHARE": DoubleType() (nullable = True)
#  |-- "CAPEXPERSHARE": DoubleType() (nullable = True)
#  |-- "FREECASHFLOWPERSHARE": DoubleType() (nullable = True)
#  |-- "NETINCOMEPEREBT": DoubleType() (nullable = True)
#  |-- "EBTPEREBIT": DoubleType() (nullable = True)
#  |-- "PRICETOFAIRVALUE": DoubleType() (nullable = True)
#  |-- "DEBTTOMARKETCAP": DoubleType() (nullable = True)
#  |-- "EFFECTIVETAXRATE": DoubleType() (nullable = True)
#  |-- "ENTERPRISEVALUEMULTIPLE": DoubleType() (nullable = True)
#  |-- "DIVIDENDPERSHARE": DoubleType() (nullable = True)
#
# 📋 Table: stock_profiles
# root
#  |-- "MARKETCAP": LongType() (nullable = True)
#  |-- "IPODATE": StringType(32) (nullable = True)
#  |-- "CEO": StringType(128) (nullable = True)
#  |-- "CUSIP": StringType(32) (nullable = True)
#  |-- "VOLUME": LongType() (nullable = True)
#  |-- "SECTOR": StringType(32) (nullable = True)
#  |-- "IMAGE": StringType(128) (nullable = True)
#  |-- "ADDRESS": StringType(256) (nullable = True)
#  |-- "PRICE": DoubleType() (nullable = True)
#  |-- "COMPANYNAME": StringType(128) (nullable = True)
#  |-- "CIK": StringType(32) (nullable = True)
#  |-- "BETA": DoubleType() (nullable = True)
#  |-- "RANGE": StringType(32) (nullable = True)
#  |-- "ISFUND": StringType(16) (nullable = True)
#  |-- "PHONE": StringType(32) (nullable = True)
#  |-- "ISIN": StringType(32) (nullable = True)
#  |-- "LASTDIVIDEND": DoubleType() (nullable = True)
#  |-- "ISETF": StringType(16) (nullable = True)
#  |-- "AVERAGEVOLUME": DoubleType() (nullable = True)
#  |-- "EXCHANGE": StringType(16) (nullable = True)
#  |-- "ISACTIVELYTRADING": StringType(16) (nullable = True)
#  |-- "STATE": StringType(16) (nullable = True)
#  |-- "CHANGE": DoubleType() (nullable = True)
#  |-- "COUNTRY": StringType(16) (nullable = True)
#  |-- "ISADR": StringType(16) (nullable = True)
#  |-- "DESCRIPTION": StringType(8192) (nullable = True)
#  |-- "DEFAULTIMAGE": StringType(16) (nullable = True)
#  |-- "CITY": StringType(64) (nullable = True)
#  |-- "CURRENCY": StringType(16) (nullable = True)
#  |-- "WEBSITE": StringType(256) (nullable = True)
#  |-- "ZIP": StringType(32) (nullable = True)
#  |-- "EXCHANGEFULLNAME": StringType(64) (nullable = True)
#  |-- "SYMBOL": StringType(32) (nullable = True)
#  |-- "CHANGEPERCENTAGE": DoubleType() (nullable = True)
#  |-- "FULLTIMEEMPLOYEES": StringType(32) (nullable = True)
#  |-- "INDUSTRY": StringType(64) (nullable = True)
#
# 📋 Table: stock_quotes
# root
#  |-- "SYMBOL": StringType(32) (nullable = True)
#  |-- "DATE": TimestampType(timezone=TimestampTimeZone('ntz')) (nullable = True)
#  |-- "OPEN": DoubleType() (nullable = True)
#  |-- "LOW": DoubleType() (nullable = True)
#  |-- "HIGH": DoubleType() (nullable = True)
#  |-- "CLOSE": DoubleType() (nullable = True)
#  |-- "ADJCLOSE": DoubleType() (nullable = True)
#  |-- "VOLUME": LongType() (nullable = True)
#
# 📋 Table: stock_tickers
# root
#  |-- "SYMBOL": StringType(32) (nullable = True)

# %% [markdown]
# ### 📈 Create Stock Price Enriched Table
#
# This is a template - adjust based on your actual stock data columns!

# %%
# Get the first table name (assuming it contains stock price data)
# Modify this based on your actual table structure
primary_table = duckdb_tables[0] if duckdb_tables else None

if primary_table:
    print(f"Creating enriched view from: {primary_table}")
    
    # Get column names for the primary table
    table_df = session.table(f"stocks_db.raw.{primary_table}")
    columns = table_df.columns
    print(f"Available columns: {columns}")
# Out:
# Creating enriched view from: exchanges
# Available columns: ['EXCHANGE', 'NAME', 'COUNTRYNAME', 'COUNTRYCODE', 'SYMBOLSUFFIX', 'DELAY']

# %%
# Example: Create a stocks_enriched dynamic table
# CUSTOMIZE THIS based on your actual schema!

if primary_table:
    # Build the enriched DataFrame
    # This is a generic example - modify based on your columns
    raw_df = session.table(f"stocks_db.raw.{primary_table}")
    
    # Create a simple enriched view (customize based on your data)
    # Adding row_number as an example transformation
    stocks_enriched_df = raw_df.select(
        "*"
    ).with_column(
        "ingestion_timestamp", 
        F.current_timestamp()
    )
    
    # Create the dynamic table
    stocks_enriched_df.create_or_replace_dynamic_table(
        name=f"stocks_db.analytics.{primary_table}_enriched",
        warehouse="STOCKS_LAB_WH",
        lag="12 hours"
    )
    
    print(f"✅ Dynamic table '{primary_table}_enriched' created successfully")
# Out:
# ✅ Dynamic table 'exchanges_enriched' created successfully

# %% [markdown]
# ### ✅ Verify Tier 1 Dynamic Tables

# %%
# Check the enriched table
if primary_table:
    print(f"Sample data from {primary_table}_enriched:")
    session.table(f"stocks_db.analytics.{primary_table}_enriched").limit(10).show()
# Out:
# Sample data from exchanges_enriched:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# |"EXCHANGE"  |"NAME"                          |"COUNTRYNAME"             |"COUNTRYCODE"  |"SYMBOLSUFFIX"  |"DELAY"    |"INGESTION_TIMESTAMP"             |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# |AMEX        |New York Stock Exchange Arca    |United States of America  |US             |N/A             |Real-time  |2025-12-24 14:53:09.619000-08:00  |
# |BUE         |Buenos Aires Stock Exchange     |Argentina                 |AR             |.BA             |20 min     |2025-12-24 14:53:09.619000-08:00  |
# |BVC         |Colombia Stock Exchange         |Colombia                  |CO             |.CL             |15 min     |2025-12-24 14:53:09.619000-08:00  |
# |CBOE        |Chicago Board Options Exchange  |United States of America  |US             |N/A             |Real-time  |2025-12-24 14:53:09.619000-08:00  |
# |CNQ         |Canadian Securities Exchange    |Canada                    |CA             |.CN             |Real-time  |2025-12-24 14:53:09.619000-08:00  |
# |MEX         |Mexican Stock Exchange          |Mexico                    |MX             |.MX             |20 min     |2025-12-24 14:53:09.619000-08:00  |
# |NASDAQ      |NASDAQ                          |United States of America  |US             |N/A             |Real-time  |2025-12-24 14:53:09.619000-08:00  |
# |NEO         |CBOE CA                         |Canada                    |CA             |.NE             |Real-time  |2025-12-24 14:53:09.619000-08:00  |
# |NYSE        |New York Stock Exchange         |United States of America  |US             |N/A             |Real-time  |2025-12-24 14:53:09.619000-08:00  |
# |OTC         |Other OTC                       |United States of America  |US             |N/A             |Real-time  |2025-12-24 14:53:09.619000-08:00  |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Tier 2: Aggregated Metrics
#
# Create aggregated views for analytics. Customize based on your data!

# %%
# Example: Create a summary metrics dynamic table
# CUSTOMIZE THIS based on your actual schema and business requirements!

if primary_table:
    # Get the enriched table
    enriched_df = session.table(f"stocks_db.analytics.{primary_table}_enriched")
    
    # Create summary metrics (customize based on your columns)
    summary_df = enriched_df.agg(
        F.count("*").alias("total_records"),
        F.max("ingestion_timestamp").alias("last_updated")
    )
    
    # Create as a regular table (since aggregation might not support dynamic table)
    summary_df.write.mode("overwrite").save_as_table(
        f"stocks_db.analytics.data_summary"
    )
    
    print("✅ Summary metrics table created successfully")
# Out:
# ✅ Summary metrics table created successfully

# %%
# View summary
print("Data Summary:")
session.table("stocks_db.analytics.data_summary").show()
# Out:
# Data Summary:
# ------------------------------------------------------
# |"TOTAL_RECORDS"  |"LAST_UPDATED"                    |
# ------------------------------------------------------
# |14               |2025-12-24 14:53:09.619000-08:00  |
# ------------------------------------------------------

# %% [markdown]
# ### 📋 List All Dynamic Tables

# %%
# List all dynamic tables in the analytics schema
analytics_schema_ref = root.databases["stocks_db"].schemas["analytics"]
dynamic_table_collection = DynamicTableCollection(analytics_schema_ref)
dynamic_tables = list(dynamic_table_collection.iter())

print("Dynamic tables in 'analytics' schema:")
if dynamic_tables:
    for dt in dynamic_tables:
        print(f"  - {dt.name}")
else:
    print("  No dynamic tables found")
# Out:
# Dynamic tables in 'analytics' schema:
#   - EXCHANGES_ENRICHED

# %% [markdown]
# ---
# # Part 4: Incremental Refresh ⚡
#
# Demonstrate adding new data and refreshing the pipeline.

# %% [markdown]
# ### 📊 Capture Initial State

# %%
# Get current row counts
print("Current row counts in Snowflake:")
for table_name in duckdb_tables:
    count = session.table(f"stocks_db.raw.{table_name}").count()
    print(f"  {table_name}: {count:,} rows")
# Out:
# Current row counts in Snowflake:
#   exchanges: 14 rows
#   index_list: 36 rows
#   index_quotes: 111,946 rows
#   risk_premium: 44 rows
#   stock_metrics: 129,384 rows
#   stock_profiles: 11,895 rows
#   stock_quotes: 12,556,103 rows
#   stock_tickers: 11,895 rows

# %% [markdown]
# ### ➕ Re-sync Data (Optional)
#
# Re-run the ingestion to refresh data from DuckDB.

# %%
# Re-sync uses the same load_table_to_snowflake function defined earlier
# Uncomment to re-sync all tables from DuckDB:

# for table_name in duckdb_tables:
#     name, row_count, elapsed = load_table_to_snowflake(table_name)
#     print(f"🔄 Re-synced {name}: {row_count:,} rows in {elapsed:.2f}s")

# %% [markdown]
# ### 🔄 Trigger Dynamic Table Refresh

# %%
# Refresh dynamic tables
if primary_table:
    print(f"Refreshing {primary_table}_enriched...")
    session.sql(f"ALTER DYNAMIC TABLE stocks_db.analytics.{primary_table}_enriched REFRESH").collect()
    print("✅ Dynamic tables refreshed")
# Out:
# Refreshing exchanges_enriched...
# ✅ Dynamic tables refreshed

# %% [markdown]
# ### 📜 Check Refresh History

# %%
# Check refresh history
if primary_table:
    print(f"Refresh history for {primary_table}_enriched:")
    session.sql(f"""
        SELECT name, refresh_action, state, refresh_start_time, refresh_trigger
        FROM TABLE(INFORMATION_SCHEMA.DYNAMIC_TABLE_REFRESH_HISTORY(
            NAME => 'stocks_db.ANALYTICS.{primary_table.upper()}_ENRICHED'
        ))
        ORDER BY refresh_start_time DESC 
        LIMIT 5
    """).show()
# Out:
# Refresh history for exchanges_enriched:
# ------------------------------------------------------------------------------------------------------------
# |"NAME"              |"REFRESH_ACTION"  |"STATE"    |"REFRESH_START_TIME"              |"REFRESH_TRIGGER"  |
# ------------------------------------------------------------------------------------------------------------
# |EXCHANGES_ENRICHED  |NO_DATA           |SUCCEEDED  |2025-12-24 14:53:15.019000-08:00  |MANUAL             |
# |EXCHANGES_ENRICHED  |FULL              |SUCCEEDED  |2025-12-24 14:53:09.758000-08:00  |CREATION           |
# ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
# # 🧹 Cleanup (Optional)
#
# > ⚠️ **Warning:** This will permanently delete all data and objects created in this notebook.

# %%
# Close DuckDB connection
duck_conn.close()
print("🦆 DuckDB connection closed")
# Out:
# 🦆 DuckDB connection closed

# %%
# Uncomment the following lines to perform Snowflake cleanup

# # Drop database
# root.databases["stocks_db"].delete()
# print("Database 'stocks_db' dropped")

# # Drop warehouse
# root.warehouses["STOCKS_LAB_WH"].delete()
# print("Warehouse 'STOCKS_LAB_WH' dropped")

print("Cleanup section ready (uncomment to execute)")
# Out:
# Cleanup section ready (uncomment to execute)

# %%
# Close the Snowflake session
session.close()
print("❄️ Snowflake session closed")
# Out:
# ❄️ Snowflake session closed

# %% [markdown]
# ---
# # 🎉 Summary & Resources
#
# ## What We Built
#
# | Component | Description |
# |-----------|-------------|
# | **DuckDB Integration** | Read data from local DuckDB database |
# | **Optimized Schema** | VARCHAR columns sized based on actual data |
# | **Data Ingestion** | Bulk upload to Snowflake raw tables |
# | **Dynamic Tables** | Automatic transformation pipeline |
# | **Incremental Refresh** | Efficient data updates |
#
# ## Technologies Used
#
# | Tool | Purpose |
# |------|---------|
# | **DuckDB** | Local analytical database |
# | **Pandas** | Data interchange format |
# | **Snowflake Python APIs** | Database/schema/table management |
# | **Snowpark DataFrames** | Data querying and transformation |
# | **Dynamic Tables** | Declarative pipeline orchestration |
#
# ---
#
# ## 📚 Additional Resources
#
# - [DuckDB Documentation](https://duckdb.org/docs/)
# - [Snowflake Dynamic Tables](https://docs.snowflake.com/en/user-guide/dynamic-tables-intro)
# - [Snowpark Python Developer Guide](https://docs.snowflake.com/en/developer-guide/snowpark/python/index)
# - [Snowflake Python API Reference](https://docs.snowflake.com/developer-guide/snowflake-python-api/reference/latest/index)
